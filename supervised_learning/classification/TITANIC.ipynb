# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("/content/train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop(['PassengerId','Name','Ticket'],axis=1,inplace=True)

# %%
df["Age"].replace(np.nan,df['Age'].astype("float").median(axis=0),inplace=True)
df["Cabin"].replace(np.nan,df["Cabin"].mode()[0],inplace=True)
df["Embarked"].replace(np.nan,df["Embarked"].mode()[0],inplace=True)

# %%
df.Embarked=df.Embarked.replace(['S','C','Q'],[0,1,2])

# %%
df["Cabin"].replace(np.nan,df["Cabin"].mode()[0],inplace=True)
df.Sex=df.Sex.replace(['male','female'],[0,1])
df["Embarked"].replace(np.nan,df["Embarked"].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
dft=pd.read_csv("/content/test.csv")

# %%
dft
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
dft.drop(['PassengerId','Name','Ticket'],axis=1,inplace=True)

# %%
dft.isnull().sum()
# Out:
# Pclass        0
# Sex           0
# Age          86
# SibSp         0
# Parch         0
# Fare          1
# Cabin       327
# Embarked      0
# dtype: int64

# %%
dft["Age"].replace(np.nan,dft['Age'].astype("float").median(axis=0),inplace=True)
dft.Embarked=dft.Embarked.replace(['S','C','Q'],[0,1,2])
dft["Cabin"].replace(np.nan,dft["Cabin"].mode()[0],inplace=True) #mode will return as series
dft["Fare"].replace(np.nan,dft['Fare'].astype("float").median(axis=0),inplace=True)
dft.Sex=dft.Sex.replace(['male','female'],[0,1])

# %%
dft.isnull().sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
dft.dtypes
# Out:
# Pclass        int64
# Sex           int64
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# Cabin        object
# Embarked      int64
# dtype: object

# %%
import seaborn as sns

# %%
sns.heatmap(dft.corr(),cmap='PuOr',annot=True)
# Out:
# <ipython-input-178-0cd7d02d81ea>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(dft.corr(),cmap='PuOr',annot=True)
# <Axes: >

# %%
train_y=df["Survived"]
train_x=df[["Pclass","Sex","Age","SibSp","Parch","Fare","Embarked"]]

# %%
df_encoded = pd.get_dummies(df, columns=['Embarked'], prefix='Embarked')

# %%
df['Embarked'] = df['Embarked'].astype(float)

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex           int64
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# Cabin        object
# Embarked    float64
# dtype: object

# %% [markdown]
# NAVIE BAYES

# %%
from sklearn.model_selection import train_test_split
train_data,val_data,train_target,val_target=train_test_split(train_x,train_y,test_size=0.8)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model=GaussianNB()
model.fit(train_data,train_target)
val_pred=model.predict(val_data)

# %%
from sklearn.metrics import accuracy_score
print("Model accuracy score: {0:0.4}".format(accuracy_score(val_target,val_pred)*100)+"%")
# Out:
# Model accuracy score: 78.4%

# %% [markdown]
# LOGISTRIC REGRESSION

# %%
from sklearn import linear_model

# %%
model = linear_model.LogisticRegression()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(train_x,train_y,train_size=0.8)

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [[-1.00076526e+00  2.73261626e+00 -3.18034552e-02 -2.99484862e-01
#   -6.52584991e-02  2.61397203e-03  1.28921853e-01]]
# [1.67052552]

# %%
y_predicted=model.predict(x_test)

# %%
print("Test data score",model.score(x_test,y_test))
print("Train data score",model.score(x_train,y_train))
# Out:
# Test data score 0.7597765363128491
# Train data score 0.8103932584269663
