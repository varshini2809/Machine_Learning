# %% [markdown]
# <a href="https://colab.research.google.com/github/varshini2809/ML/blob/main/SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import seaborn as sns
from matplotlib  import pyplot as plt
from sklearn.svm import SVC
from sklearn import svm
import numpy as no

# %%
df=pd.read_csv("https://raw.githubusercontent.com/ezioauditore-tech/AI/main/datasets/Titanic/train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop(['PassengerId','Name','Ticket'],axis=1,inplace=True)
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df[df.Embarked.isnull()]
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch  Fare Cabin Embarked
# 61          1       1  female  38.0      0      0  80.0   B28      NaN
# 829         1       1  female  62.0      0      0  80.0   B28      NaN

# %%
df.drop(['Cabin'],axis=1,inplace=True)

# %%
df['Age']=df['Age'].fillna(df['Age'].median())
df['Embarked']=df['Embarked'].fillna("C")
df.Sex=df.Sex.replace(['male','female'],[0,1])
df.Embarked=df.Embarked.replace(['S','C','Q'],[0,1,2])

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0           0       3    0  22.0      1      0   7.2500         0
# 1           1       1    1  38.0      1      0  71.2833         1
# 2           1       3    1  26.0      0      0   7.9250         0
# 3           1       1    1  35.0      1      0  53.1000         0
# 4           0       3    0  35.0      0      0   8.0500         0
# ..        ...     ...  ...   ...    ...    ...      ...       ...
# 885         0       3    1  39.0      0      5  29.1250         2
# 886         0       2    0  27.0      0      0  13.0000         0
# 887         1       1    1  19.0      0      0  30.0000         0
# 889         1       1    0  26.0      0      0  30.0000         1
# 890         0       3    0  32.0      0      0   7.7500         2
#
# [712 rows x 8 columns]

# %%
df1=pd.read_csv("https://raw.githubusercontent.com/ezioauditore-tech/AI/main/datasets/Titanic/test.csv")

# %%
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df1.drop(['PassengerId','Name','Ticket'],axis=1,inplace=True)
df1.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0       3    male  34.5      0      0   7.8292   NaN        Q
# 1       3  female  47.0      1      0   7.0000   NaN        S
# 2       2    male  62.0      0      0   9.6875   NaN        Q
# 3       3    male  27.0      0      0   8.6625   NaN        S
# 4       3  female  22.0      1      1  12.2875   NaN        S

# %%
df1.isnull().sum()
# Out:
# Pclass        0
# Sex           0
# Age          86
# SibSp         0
# Parch         0
# Fare          1
# Cabin       327
# Embarked      0
# dtype: int64

# %%
df1.drop(['Cabin'],axis=1,inplace=True)

# %%
df1['Age']=df1['Age'].fillna(df1['Age'].median())
df1['Embarked']=df1['Embarked'].fillna("C")
df1.Sex=df1.Sex.replace(['male','female'],[0,1])
df1.Embarked=df1.Embarked.replace(['S','C','Q'],[0,1,2])

# %%
df1.dropna(inplace=True)

# %%
features=["Pclass","Sex","Age","SibSp","Parch","Fare","Embarked"]

# %%
c=0.7
clf=svm.SVC(kernel='linear',C=c).fit(df[features],df["Survived"])

# %%
prediction=clf.predict(df1[features])

# %%
df1
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare  Embarked
# 0         3    0  34.5      0      0    7.8292         2
# 1         3    1  47.0      1      0    7.0000         0
# 2         2    0  62.0      0      0    9.6875         2
# 3         3    0  27.0      0      0    8.6625         0
# 4         3    1  22.0      1      1   12.2875         0
# ..      ...  ...   ...    ...    ...       ...       ...
# 413       3    0  27.0      0      0    8.0500         0
# 414       1    1  39.0      0      0  108.9000         1
# 415       3    0  38.5      0      0    7.2500         0
# 416       3    0  27.0      0      0    8.0500         0
# 417       3    0  27.0      1      1   22.3583         1
#
# [417 rows x 7 columns]
